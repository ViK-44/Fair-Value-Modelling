# %%
import pandas as pd

# %%
df = pd.read_csv("Temp_CAINWPPSW_10yrs.csv")

# %%
df.head(30)
# Out:
#                datetime     datatype  avgvalue     siteid               name  \
# 0   2025-09-02 11:00:00  temperature      76.0       KGEG  WA - Spokane/Intl
# 1   2025-09-02 12:00:00  temperature      74.0       KGEG  WA - Spokane/Intl
# 2   2025-09-02 13:00:00  temperature      73.0       KGEG  WA - Spokane/Intl
# 3   2025-09-02 14:00:00  temperature      71.0       KGEG  WA - Spokane/Intl
# 4   2025-09-02 15:00:00  temperature      73.0       KGEG  WA - Spokane/Intl
# 5   2025-09-02 16:00:00  temperature      78.0       KGEG  WA - Spokane/Intl
# 6   2025-09-02 17:00:00  temperature      81.0       KGEG  WA - Spokane/Intl
# 7   2025-09-02 18:00:00  temperature      84.0       KGEG  WA - Spokane/Intl
# 8   2025-09-02 19:00:00  temperature      88.0       KGEG  WA - Spokane/Intl
# 9   2025-09-02 20:00:00  temperature      92.0       KGEG  WA - Spokane/Intl
# 10  2025-09-02 21:00:00  temperature      95.0       KGEG  WA - Spokane/Intl
# ...
